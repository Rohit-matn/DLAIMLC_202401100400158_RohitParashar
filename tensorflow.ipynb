# %%
import numpy as np
import tensorflow as tf
x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)
model=tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])
model.compile(optimizer='sgd',loss='mean_squared_error')
model.fit(x,y,epochs=20)
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 52.5502
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 36.4961
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 25.3563
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 17.6265
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 12.2627
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 8.5407
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 5.9579
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 4.1655
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 2.9217
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.0584
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.4592
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.0433
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.7545
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.5539
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4145
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3176
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.2502
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2033
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1705
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1476

# %%
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)
model=Sequential([
    Dense(1,input_shape=(1,))]
)
model.compile(optimizer='sgd',loss='mean_squared_error')
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - loss: 28.9105
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 20.0783
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 13.9498
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 9.6972
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6.7463
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 4.6987
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 3.2777
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.2917
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.6074
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.1324

# %%
import torch
import torch.optim as optim
import torch.nn as nn
model = nn.Linear(1, 1)
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)
x = torch.tensor([[1.], [2.], [3.], [4.]])
y = torch.tensor([[2.], [4.], [6.], [8.]])
for epoch in range(10):
    optimizer.zero_grad()
    outputs = model(x)
    loss = criterion(outputs, y)
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item():.6f}")
# Out:
# Epoch 1, Loss: 44.998135
# Epoch 2, Loss: 31.223675
# Epoch 3, Loss: 21.665861
# Epoch 4, Loss: 15.033897
# Epoch 5, Loss: 10.432115
# Epoch 6, Loss: 7.239031
# Epoch 7, Loss: 5.023416
# Epoch 8, Loss: 3.486045
# Epoch 9, Loss: 2.419293
# Epoch 10, Loss: 1.679094
